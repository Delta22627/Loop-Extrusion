# %%
import numpy as np
import matplotlib.pyplot as plt
from LoopExtrusionModel.loopExtrusionModel import Genome, Cohesin, Extruder, Simulator

# %%
def simulations(i, time, n_extruders=500, per_i=10, option="cohesin"):
    sim = Simulator(Genome(1), i, n_extruders, per_i, option)
    sim.simulate(time)
    sim.plot()
    sim.average_domain()
    return sim.extruders_domains

# %%
def sim_per_i(per_i, option):
    all_domains = dict()
    for i in range(10):
        extruders_domains = simulations(i, time=200, per_i=per_i, option=option)
        for key in extruders_domains:
            if all_domains.get(key) is None:
                all_domains[key] = extruders_domains[key]
            else:
                all_domains[key].extend(extruders_domains[key])
    plt.show()
    print([(k ,np.mean(x)) for k, x in all_domains.items()])
    labels, data = [*zip(*all_domains.items())]
    plt.boxplot(data)
    plt.xticks(range(1, len(labels) + 1), labels)
    plt.show()

# %%
def run(option):
    for i in range(1,11):
        sim_per_i(i*10, option)

# %%
run("cohesin")
# Out:
# [('Cohesin', 11.6966)]
# [('Cohesin', 12.4508)]
# [('Cohesin', 12.7862)]
# [('Cohesin', 13.1414)]
# [('Cohesin', 13.4572)]
# [('Cohesin', 13.8774)]
# [('Cohesin', 13.9554)]
# [('Cohesin', 14.2038)]
# [('Cohesin', 14.3978)]
# [('Cohesin', 14.5648)]

# %%
run("both")
# Out:
# [('Cohesin', 11.2812), ('Condensin', 20.8148)]
# [('Cohesin', 12.1296), ('Condensin', 23.1852)]
# [('Cohesin', 12.5936), ('Condensin', 25.3156)]
# [('Cohesin', 12.884), ('Condensin', 27.2056)]
# [('Cohesin', 12.942), ('Condensin', 27.7436)]
# [('Cohesin', 13.322), ('Condensin', 28.3268)]
# [('Cohesin', 13.2836), ('Condensin', 29.7208)]
# [('Cohesin', 13.7), ('Condensin', 31.7032)]
# [('Cohesin', 13.7092), ('Condensin', 31.7124)]
# [('Cohesin', 13.4728), ('Condensin', 31.9172)]

# %%
run("both_0.2")
# Out:
# [('Cohesin', 19.0544), ('Condensin', 22.738)]
# [('Cohesin', 21.4636), ('Condensin', 26.0944)]
# [('Cohesin', 22.6208), ('Condensin', 28.3852)]
# [('Cohesin', 25.134), ('Condensin', 31.6692)]
# [('Cohesin', 26.2592), ('Condensin', 33.2792)]
# [('Cohesin', 27.2056), ('Condensin', 34.9032)]
# [('Cohesin', 27.798), ('Condensin', 36.5612)]
# [('Cohesin', 29.4004), ('Condensin', 38.458)]
# [('Cohesin', 30.592), ('Condensin', 40.9844)]
# [('Cohesin', 29.6484), ('Condensin', 39.8304)]

# %%
run("both_d_0.5")
# Out:
# [('Cohesin', 4.111063280241067), ('Condensin', 4.357758620689655)]
# [('Cohesin', 4.080707811825636), ('Condensin', 4.269345874305259)]
# [('Cohesin', 3.99018771331058), ('Condensin', 4.2832469775474955)]
# [('Cohesin', 4.082545141874463), ('Condensin', 4.315496575342466)]
# [('Cohesin', 4.067266495287061), ('Condensin', 4.3409581355200695)]
# [('Cohesin', 4.096194955109021), ('Condensin', 4.288831835686778)]
# [('Cohesin', 4.085994040017028), ('Condensin', 4.322705730288669)]
# [('Cohesin', 4.117798796216681), ('Condensin', 4.270923209663503)]
# [('Cohesin', 4.0725875320239115), ('Condensin', 4.265638389031706)]
# [('Condensin', 4.369939707149009), ('Cohesin', 3.9991463935125906)]
