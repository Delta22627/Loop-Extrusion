# %%
import numpy as np
import matplotlib.pyplot as plt
from LoopExtrusionModel.loopExtrusionModel import Genome, Cohesin, Extruder, Simulator

# %%
def simulations(i, time, n_extruders=10000, per_i=10, option="cohesin"):
    sim = Simulator(Genome(1), i, n_extruders, per_i, option)
    sim.simulate(time)
    sim.plot()
    sim.average_domain()
    return sim.extruders_domains

# %%
def sim_per_i(per_i, option):
    all_domains = dict()
    for i in range(10):
        extruders_domains = simulations(i, time=200, per_i=per_i, option=option)
        for key in extruders_domains:
            if all_domains.get(key) is None:
                all_domains[key] = extruders_domains[key]
            else:
                all_domains[key].extend(extruders_domains[key])
    plt.savefig(f"sim_image_10000/{option} per {per_i} Extruders.png")
    plt.show()
    print([(k ,np.mean(x)) for k, x in all_domains.items()])
    labels, data = [*zip(*all_domains.items())]
    plt.boxplot(data)
    plt.xticks(range(1, len(labels) + 1), labels)
    plt.savefig(f"sim_image_10000/{option} per {per_i} Boxplot.png")
    plt.show()

# %%
def run(option):
    for i in range(1,11):
        sim_per_i(i*10, option)

# %%
run("cohesin")
# Out:
# [('Cohesin', 2.764846786585917)]
# [('Cohesin', 3.2570054791457004)]
# [('Cohesin', 3.6133401425494593)]
# [('Cohesin', 3.8752235247367377)]
# [('Cohesin', 4.101154795486601)]
# [('Cohesin', 4.246063294753256)]
# [('Cohesin', 4.406062997303874)]
# [('Cohesin', 4.517931682584085)]
# [('Cohesin', 4.674952491208143)]
# [('Cohesin', 4.779441901024635)]

# %%
run("both")
# Out:
# [('Condensin', 2.8572008296510054), ('Cohesin', 2.7426613157776076)]
# [('Condensin', 3.4528150849417414), ('Cohesin', 3.2591235985169966)]
# [('Condensin', 3.8830055248618787), ('Cohesin', 3.592873624423145)]
# [('Condensin', 4.171165617156194), ('Cohesin', 3.858230762419198)]
# [('Condensin', 4.480818301803784), ('Cohesin', 4.029445422535211)]
# [('Condensin', 4.720802599227257), ('Cohesin', 4.217480922726077)]
# [('Condensin', 4.942194515889969), ('Cohesin', 4.349149113935183)]
# [('Condensin', 5.108727939891665), ('Cohesin', 4.44750415246088)]
# [('Condensin', 5.2425283856092575), ('Cohesin', 4.57169166008945)]
# [('Condensin', 5.439965019676432), ('Cohesin', 4.683430663296435)]

# %%
run("both_0.2")
# Out:
# [('Condensin', 2.8550289224698444), ('Cohesin', 2.8375061584628476)]
# [('Condensin', 3.485916114790287), ('Cohesin', 3.4583314912241923)]
# [('Condensin', 3.948861646234676), ('Cohesin', 3.921464357915092)]
# [('Condensin', 4.259149658383742), ('Cohesin', 4.252691466083151)]
# [('Condensin', 4.629108592766271), ('Cohesin', 4.54509735440496)]
# [('Condensin', 4.860579006674179), ('Cohesin', 4.8199722366822835)]
# [('Condensin', 5.103042876901798), ('Cohesin', 5.016897014860708)]
# [('Condensin', 5.304220751310925), ('Cohesin', 5.203792293641819)]
# [('Condensin', 5.53442792057079), ('Cohesin', 5.396721736873973)]
# [('Condensin', 5.720806292173465), ('Cohesin', 5.539466873706004)]

# %%
run("both_d_0.5")
# Out:
# [('Condensin', 1.8234822451317296), ('Cohesin', 1.8219420356001825)]
# [('Condensin', 1.8257388098392764), ('Cohesin', 1.8278801052511153)]
# [('Condensin', 1.820670422855842), ('Cohesin', 1.8075534414579633)]
# [('Condensin', 1.8330281528953993), ('Cohesin', 1.81723387189183)]
# [('Condensin', 1.8379566210045661), ('Cohesin', 1.8228188687886422)]
# [('Condensin', 1.8205566963267168), ('Cohesin', 1.8119418365010305)]
# [('Condensin', 1.8255141204101506), ('Cohesin', 1.820179705831855)]
# [('Condensin', 1.8359890735260642), ('Cohesin', 1.8230733892270587)]
# [('Condensin', 1.830471486820192), ('Cohesin', 1.8259030635573845)]
# [('Condensin', 1.8324348862282245), ('Cohesin', 1.8200184183262347)]
