# %%
import numpy as np
import matplotlib.pyplot as plt
from LoopExtrusionModel.loopExtrusionModel import Genome, Cohesin, Extruder, Simulator

# %%
def simulations(i, time, n_extruders=500, per_i=10, option="cohesin"):
    sim = Simulator(Genome(1), i, n_extruders, per_i, option)
    sim.simulate(time)
    sim.plot()
    sim.average_domain()
    return sim.extruders_domains

# %%
def sim_per_i(per_i, option):
    all_domains = dict()
    for i in range(10):
        extruders_domains = simulations(i, time=200, per_i=per_i, option=option)
        for key in extruders_domains:
            if all_domains.get(key) is None:
                all_domains[key] = extruders_domains[key]
            else:
                all_domains[key].extend(extruders_domains[key])
    plt.show()
    print([(k ,np.mean(x)) for k, x in all_domains.items()])
    labels, data = [*zip(*all_domains.items())]
    plt.boxplot(data)
    plt.xticks(range(1, len(labels) + 1), labels)
    plt.show()

# %%
def run(option):
    for i in range(1,11):
        sim_per_i(i*10, option)

# %%
run("cohesin")
# Out:
# [('Cohesin', 11.6838)]
# [('Cohesin', 12.4154)]
# [('Cohesin', 13.1408)]
# [('Cohesin', 13.2496)]
# [('Cohesin', 13.7018)]
# [('Cohesin', 13.8378)]
# [('Cohesin', 14.0006)]
# [('Cohesin', 14.0494)]
# [('Cohesin', 14.364)]
# [('Cohesin', 14.2462)]

# %%
run("both")
# Out:
# [('Cohesin', 11.2752), ('Condensin', 21.24)]
# [('Cohesin', 11.9332), ('Condensin', 23.4188)]
# [('Cohesin', 12.4132), ('Condensin', 25.7752)]
# [('Cohesin', 12.8356), ('Condensin', 27.094)]
# [('Cohesin', 12.69), ('Condensin', 28.1064)]
# [('Cohesin', 13.1956), ('Condensin', 28.9956)]
# [('Cohesin', 13.2588), ('Condensin', 30.5796)]
# [('Cohesin', 13.6136), ('Condensin', 31.7724)]
# [('Cohesin', 13.6464), ('Condensin', 32.6532)]
# [('Cohesin', 13.56), ('Condensin', 33.1496)]

# %%
run("both_0.2")
# Out:
# [('Cohesin', 18.9984), ('Condensin', 22.3988)]
# [('Cohesin', 21.7208), ('Condensin', 25.8876)]
# [('Cohesin', 23.2504), ('Condensin', 28.7716)]
# [('Cohesin', 24.7248), ('Condensin', 31.2)]
# [('Cohesin', 25.7104), ('Condensin', 32.7044)]
# [('Cohesin', 27.1748), ('Condensin', 35.0644)]
# [('Cohesin', 28.3028), ('Condensin', 35.93)]
# [('Cohesin', 29.1148), ('Condensin', 38.1652)]
# [('Cohesin', 30.3756), ('Condensin', 40.3332)]
# [('Cohesin', 30.6928), ('Condensin', 39.5912)]

# %%
run("both_d_0.5")
# Out:
# [('Cohesin', 4.129797326433808), ('Condensin', 4.372793801119243)]
# [('Cohesin', 4.0259133389974515), ('Condensin', 4.402843601895735)]
# [('Cohesin', 4.063334769495907), ('Condensin', 4.288527397260274)]
# [('Cohesin', 4.0238297872340425), ('Condensin', 4.336464560204953)]
# [('Cohesin', 4.097318339100346), ('Condensin', 4.432765957446809)]
# [('Cohesin', 4.068832834544677), ('Condensin', 4.405254091300603)]
# [('Cohesin', 4.020574367766824), ('Condensin', 4.272882805816938)]
# [('Cohesin', 4.016421780466724), ('Condensin', 4.339719029374201)]
# [('Cohesin', 4.043384879725086), ('Condensin', 4.282073067119796)]
# [('Cohesin', 4.0988347000431595), ('Condensin', 4.387798634812286)]
