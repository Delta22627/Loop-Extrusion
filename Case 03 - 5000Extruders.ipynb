# %%
import numpy as np
import matplotlib.pyplot as plt
from LoopExtrusionModel.loopExtrusionModel import Genome, Cohesin, Extruder, Simulator

# %%
def simulations(i, time, n_extruders=5000, per_i=10, option="cohesin"):
    sim = Simulator(Genome(1), i, n_extruders, per_i, option)
    sim.simulate(time)
    sim.plot()
    sim.average_domain()
    return sim.extruders_domains

# %%
def sim_per_i(per_i, option):
    all_domains = dict()
    for i in range(10):
        extruders_domains = simulations(i, time=200, per_i=per_i, option=option)
        for key in extruders_domains:
            if all_domains.get(key) is None:
                all_domains[key] = extruders_domains[key]
            else:
                all_domains[key].extend(extruders_domains[key])
    plt.show()
    print([(k ,np.mean(x)) for k, x in all_domains.items()])
    labels, data = [*zip(*all_domains.items())]
    plt.boxplot(data)
    plt.xticks(range(1, len(labels) + 1), labels)
    plt.show()

# %%
for i in range(1,11):
    sim_per_i(i*10, "cohesin")
# Out:
# [('Cohesin', 3.292391911518266)]
# [('Cohesin', 3.8653519136061485)]
# [('Cohesin', 4.266997867710097)]
# [('Cohesin', 4.535311105276976)]
# [('Cohesin', 4.7635390496996175)]
# [('Cohesin', 4.962951695964885)]
# [('Cohesin', 5.113968033356498)]
# [('Cohesin', 5.2664090149163)]
# [('Cohesin', 5.400688192520776)]
# [('Cohesin', 5.509633890534784)]

# %%
for i in range(1,11):
    sim_per_i(i*10, "both")
# Out:
# [('Cohesin', 3.2454820617822486), ('Condensin', 3.502452073116362)]
# [('Cohesin', 3.809220704592671), ('Condensin', 4.252445580329603)]
# [('Cohesin', 4.19482229047828), ('Condensin', 4.74604082350871)]
# [('Cohesin', 4.43568899960666), ('Condensin', 5.139852786540484)]
# [('Cohesin', 4.648257208916808), ('Condensin', 5.456957109821546)]
# [('Cohesin', 4.789672708306168), ('Condensin', 5.725353341476183)]
# [('Cohesin', 4.968099439349819), ('Condensin', 6.001957883745214)]
# [('Cohesin', 5.083874599463064), ('Condensin', 6.225624321389794)]
# [('Cohesin', 5.243770548537809), ('Condensin', 6.4060235212428935)]
# [('Cohesin', 5.301960275217448), ('Condensin', 6.582587258336577)]

# %%
for i in range(1,11):
    sim_per_i(i*10, "both_0.2")
# Out:
# [('Cohesin', 3.462620118134532), ('Condensin', 3.523501814641055)]
# [('Cohesin', 4.222144603562697), ('Condensin', 4.340189942667076)]
# [('Cohesin', 4.772376409366869), ('Condensin', 4.923477129850423)]
# [('Cohesin', 5.1746935957189715), ('Condensin', 5.375097512351565)]
# [('Cohesin', 5.5080780664340185), ('Condensin', 5.748109416187718)]
# [('Cohesin', 5.7814217032967035), ('Condensin', 6.081765059723296)]
# [('Cohesin', 6.118138578223422), ('Condensin', 6.421842184218422)]
# [('Cohesin', 6.329638822321123), ('Condensin', 6.665425918795191)]
# [('Cohesin', 6.568954512573933), ('Condensin', 6.9842249657064475)]
# [('Cohesin', 6.723163116927551), ('Condensin', 7.105767175409346)]

# %%
for i in range(1,11):
    sim_per_i(i*10, "both_d_0.5")
# Out:
# [('Cohesin', 2.315144266706533), ('Condensin', 2.3584047707789786)]
# [('Cohesin', 2.2974328268842155), ('Condensin', 2.3488941665429715)]
# [('Cohesin', 2.298732289336316), ('Condensin', 2.3583650900396025)]
# [('Condensin', 2.3461852153926004), ('Cohesin', 2.309442379182156)]
# [('Cohesin', 2.3202205334525408), ('Condensin', 2.359173319406103)]
# [('Cohesin', 2.310997978588006), ('Condensin', 2.35164590747331)]
# [('Condensin', 2.338709677419355), ('Cohesin', 2.316546762589928)]
# [('Cohesin', 2.313296089385475), ('Condensin', 2.355919583023083)]
# [('Cohesin', 2.314360704911886), ('Condensin', 2.3365171035095513)]
# [('Condensin', 2.351050404572786), ('Cohesin', 2.3114534494306764)]
